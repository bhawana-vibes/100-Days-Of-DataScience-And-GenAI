# %%
print("bhawana")

# %%
#1 program
a = 2
b = 3
sum = a+b
print(sum)
# Out:
# 5

# %%
#input user program
num1 = float(input("enter first number: "))
num2 = float(input("enter second number: "))
sum = num1+num2
print(sum)
# Out:
# 12.0

# %%
print("hello world")
# Out:
# hello world

# %%
num = 25
#num1 = int(input("enter the number:"))
sr = num**(1/2)
print("the square root:", sr)
# Out:
# the square root: 5.0

# %%
num1 = float(input("enter the number:"))
sr = num1**(1/2)
print("the square root:", sr)
# Out:
# the square root: 2.449489742783178

# %%
import math
num3 = int(input("enter the square:"))
sr = math.sqrt(num3)
print(sr)
# Out:
# 2.6457513110645907

# %%
height = float(input("the enter height:"))
base = float(input("the enter base:"))
area = (0.5*base*height)
print(area)
# Out:
# 15.0

# %%
x = 2
y = 3
temp = x
print("the swap value:", temp)
x = y
temp = y
print("the swap  x value:",temp)
# Out:
# the swap value: 2
# the swap  x value: 3

# %%
x = 4
y = 5
x,y = y,x
print("the swap x value is:",x)
print("the swap y value is:",y)
# Out:
# the swap x value is: 5
# the swap y value is: 4

# %%
import random
num4 = random.randint(0,10)
print(num4)
# Out:
# 9

# %%
km = float(50)
convertor_factor = 0.621371
miles = convertor_factor*km
print(miles)
# Out:
# 31.068550000000002

# %%
cel = int(40)
f = (cel*9/5)+32
print("the fahrenheit value:", f)
# Out:
# the fahrenheit value: 104.0

# %%
cel = int(input("the value of celsius:"))
f = (cel*9/5)+32
print("the fahrenheit value:", f)
# Out:
# the fahrenheit value: 122.0
